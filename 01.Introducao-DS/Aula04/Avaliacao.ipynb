# %% [markdown]
# # Avaliação Aula 04 - Introdução Ciência de Dados

# %% [markdown]
# # Exercicio 1
#
#
# Considere os dados gerados pelo código abaixo. Determine o número ideal de clusters usando a medida normalized mutual information. Use o métodos k-mean para encontrar os clusters.
# ```python
# from sklearn.datasets import make_blobs
# from sklearn.cluster import KMeans
# import numpy as np
# import matplotlib.pyplot as plt
#
# np.random.seed(10)
#
# #create blobs
# k = 5
# n=200
# data = make_blobs(n_samples=n, n_features=2, centers=k, cluster_std=1.5, random_state=50)
# X = data[0]
# labels = data[1]
# plt.scatter(X[:,0], X[:,1], c=labels, cmap='viridis', s=50, alpha=0.9)
# plt.xlim(-15,15)
# plt.ylim(-15,15)
# plt.show(True)
# ```
# Escolha uma:<br>
# <b>a. 10</b> <br>
# <b>b. 1</b> <br>
# <b>c. 5</b> <br>
# <b>d. 2</b> <br>
# <b>e. 8</b> <br>

# %%
from sklearn.datasets import make_blobs
from sklearn.cluster import KMeans
from sklearn.metrics.cluster import adjusted_rand_score, normalized_mutual_info_score
from sklearn import cluster

import numpy as np
np.random.seed(10)

import numpy as np
import matplotlib.pyplot as plt


print("Resposta: ", '5')

#create blobs
k = 5
n=200
data = make_blobs(n_samples=n, n_features=2, centers=k, cluster_std=1.5, random_state=50)
X = data[0]
labels = data[1]
plt.scatter(X[:,0], X[:,1], c=labels, cmap='viridis', s=50, alpha=0.9)
plt.xlim(-15,15)
plt.ylim(-15,15)
plt.title('Original Data')
plt.show(True)

NMI_km = []
NMI_hr = []
K = range(1,10)

for i in K:
    kmeans = KMeans(n_clusters=i)
    kmeans.fit(X)
    y_km = kmeans.fit_predict(X)
    NMI_km.append(normalized_mutual_info_score(y_km, data[1], average_method='arithmetic'))
    clustering = cluster.AgglomerativeClustering(n_clusters=i, linkage='ward')
    y_hr = clustering.fit_predict(X)
    NMI_hr.append(normalized_mutual_info_score(y_hr, data[1], average_method='arithmetic'))
    
plt.plot(K, NMI_km, '-bo', label = 'kmeans')
#plt.plot(K, NMI_hr, '-ro', label = 'hierarchical (Ward)')
plt.xlabel('k', fontsize = 15)
plt.ylabel('Normalized Mutual information', fontsize = 15)
plt.grid(True)
plt.legend()
plt.show()

kmeans = KMeans(n_clusters=k)
kmeans.fit(X)
y_km = kmeans.fit_predict(X)
plt.figure(figsize=(13,5))
plt.subplot(1, 2, 1)
plt.scatter(X[:,0], X[:,1], c=y_km, cmap='viridis', s=50, alpha=0.9)
plt.xlim(-15,15)
plt.ylim(-15,15)
plt.title('K-means')
centers = kmeans.cluster_centers_
plt.scatter(centers[:, 0], centers[:, 1], c='red', s=100, alpha=0.9);

plt.show(True)
# Out:
# Resposta:  5

# %% [markdown]
# # Exercicio 2
#
# Aplique o método k-means aos dados gerados com o código abaixo. Calcule a medida Silhouette score. Selecione a alternativa mais próxima.
# ```python
# from sklearn.datasets import make_blobs
# from sklearn.cluster import KMeans
# np.random.seed(10)
# import numpy as np
# import matplotlib.pyplot as plt
#
# #create blobs
# k = 5
# n=200
# data = make_blobs(n_samples=n, n_features=2, centers=k, cluster_std=1.5, random_state=50)
# X = data[0]
# labels = data[1]
# plt.figure(figsize=(8,6))
# plt.scatter(X[:,0], X[:,1], c=labels, cmap='viridis', s=50, alpha=0.9)
# plt.xlim(-15,15)
# plt.ylim(-15,15)
# plt.show(True)
# ```
# Escolha uma:<br>
# <b>a. 0.2</b> <br>
# <b>b. 0.5</b> <br>
# <b>c. 0.1</b> <br>
# <b>d. 0.9</b> <br>
# <b>e. 1.0</b> <br>

# %%
from sklearn.datasets import make_blobs
from sklearn.cluster import KMeans
from sklearn.metrics.cluster import adjusted_rand_score, mutual_info_score
from sklearn.metrics import silhouette_score

np.random.seed(10)

import numpy as np
import matplotlib.pyplot as plt

#create blobs
k = 5
n=200
data = make_blobs(n_samples=n, n_features=2, centers=k, cluster_std=1.5, random_state=50)
X = data[0]
labels = data[1]

kmeans = KMeans(n_clusters=k)
kmeans.fit(X)
y_km = kmeans.fit_predict(X)

print("Resposta: ",'%.1f' % silhouette_score(X, y_km, metric='euclidean'))
print('\n')
print('Silhouette score:', silhouette_score(X, y_km, metric='euclidean'))


plt.scatter(X[:,0], X[:,1], c=labels, cmap='viridis', s=50, alpha=0.9)
plt.xlim(-15,15)
plt.ylim(-15,15)
plt.title('Original Data')
plt.show(True)
# Out:
# Resposta:  0.5
#
#
# Silhouette score: 0.5155582821519661

# %% [markdown]
# # Exercicio 3
#
# Aplique o algoritmo aglomerativo hierárquico com o método de Ward nos dados gerados com o código abaixo. Calcule a medida Normalized Mutual information. Selecione a alternativa mais próxima.
# ```python
# from sklearn.datasets import make_blobs
# from sklearn.cluster import KMeans
# np.random.seed(10)
#
# import numpy as np
# import matplotlib.pyplot as plt
# #create blobs
# k = 2
# n=200
# #data = make_blobs(n_samples=n, n_features=2, centers=k, cluster_std=1.5, random_state=50)
# data  = datasets.make_moons(n_samples=n, noise=.05)
# X = data[0]
# labels = data[1]
# plt.scatter(X[:,0], X[:,1], c=labels, cmap='viridis', s=50, alpha=0.9)
# plt.show(True)
# ```
#
# Escolha uma:<br>
# <b>a. 0.8</b> <br>
# <b>b. 0.6</b> <br>
# <b>c. 1.0</b> <br>
# <b>d. 0.1</b> <br>
# <b>e. 0.9</b> <br>

# %%
from sklearn.datasets import make_blobs
from sklearn.cluster import KMeans
from sklearn import datasets

from sklearn.metrics.cluster import adjusted_rand_score, normalized_mutual_info_score
from sklearn import cluster

np.random.seed(10)

import numpy as np
import matplotlib.pyplot as plt
#create blobs
k = 2
n=200
#data = make_blobs(n_samples=n, n_features=2, centers=k, cluster_std=1.5, random_state=50)
data  = datasets.make_moons(n_samples=n, noise=.05)

print("Resposta: ", f"{normalized_mutual_info_score(y_hr, data[1], average_method='arithmetic'):.2f}")
      
X = data[0]
labels = data[1]
plt.scatter(X[:,0], X[:,1], c=labels, cmap='viridis', s=50, alpha=0.9)
plt.title('Original Data')
plt.show(True)

NMI_km = []
NMI_hr = []
K = range(1,10)

for i in K:
    kmeans = KMeans(n_clusters=i)
    kmeans.fit(X)
    y_km = kmeans.fit_predict(X)
    NMI_km.append(normalized_mutual_info_score(y_km, data[1], average_method='arithmetic'))
    
    clustering = cluster.AgglomerativeClustering(n_clusters=i, linkage='ward')
    y_hr = clustering.fit_predict(X)
    NMI_hr.append(normalized_mutual_info_score(y_hr, data[1], average_method='arithmetic'))


#plt.plot(K, NMI_km, '-bo', label = 'kmeans')
plt.plot(K, NMI_hr, '-ro', label = 'hierarchical (Ward)')
plt.xlabel('k', fontsize = 15)
plt.ylabel('Normalized Mutual information', fontsize = 15)
plt.grid(True)
plt.legend()
plt.show()

clustering = cluster.AgglomerativeClustering(n_clusters=k, linkage='ward')
y_hr = clustering.fit_predict(X)

print('Mutual information score:', normalized_mutual_info_score(y_hr, data[1], average_method='arithmetic'))

plt.figure(figsize=(13,5))
plt.subplot(1,2, 1)
plt.scatter(X[:,0], X[:,1], c=y_hr, cmap='viridis', s=50)
plt.title('Aglomerative clustering: Ward')
plt.show(True)
# Out:
# Resposta:  0.66
# Mutual information score: 0.6570815231426531

# %% [markdown]
# # Exercicio 4
#
# Determine o número ideal de clusters para a base Iris usando o método k-means e a medida normalized mutual informaton.
# ```python
# from scipy.spatial.distance import cdist
# from sklearn import datasets
# import numpy as np
# np.random.seed(10)
#
# iris = datasets.load_iris()
# X = iris.data[:, :2]  # we only take the first two features.
# y = iris.target
# ```
#
# Escolha uma:<br>
# <b>a. 3</b> <br>
# <b>b. 1</b> <br>
# <b>c. 2</b> <br>
# <b>d. 5</b> <br>
# <b>e. 10</b> <br>

# %%
from scipy.spatial.distance import cdist
from sklearn import datasets
import numpy as np
import matplotlib.pyplot as plt

np.random.seed(10)

iris = datasets.load_iris()
X = iris.data[:, :2]  # we only take the first two features.
y = iris.target

print("Resposta: ",'3')

plt.scatter(X[:,0], X[:,1], c=y, cmap='viridis', s=50, alpha=0.9)
plt.title('Original Data')
plt.show(True)

#usando o método k-means
k=3
kmeans = KMeans(n_clusters=k)
kmeans.fit(X)
y_km = kmeans.fit_predict(X)

#plt.subplot(1, 2, 1)
plt.figure(figsize=(6,4))
plt.scatter(X[:,0], X[:,1], c=y_km, cmap='viridis', s=50, alpha=0.9)
plt.xlim(4,8)
plt.ylim(1.5,4.5)
plt.title('K-means')
centers = kmeans.cluster_centers_
plt.scatter(centers[:, 0], centers[:, 1], c='red', s=100, alpha=0.9);
plt.show(True)

NMI_km = []
NMI_hr = []
K = range(1,10)

for i in K:
    kmeans = KMeans(n_clusters=i)
    kmeans.fit(X)
    y_km = kmeans.fit_predict(X)
    NMI_km.append(normalized_mutual_info_score(y_km, y, average_method='arithmetic'))

plt.plot(K, NMI_km, '-bo', label = 'kmeans')
plt.xlabel('k', fontsize = 15)
plt.ylabel('Normalized Mutual information', fontsize = 15)
plt.grid(True)
plt.legend()
plt.show()
# Out:
# Resposta:  3

# %% [markdown]
# # Exercicio 5
#
# Determine o número ideal de clusters para a base Iris usando o método de agrupamento hierárquico (Ward) e a medida normalized mutual information.
#
# Escolha uma:<br>
# <b>a. 1</b> <br>
# <b>b. 10</b> <br>
# <b>c. 4</b> <br>
# <b>d. 5</b> <br>
# <b>e. 2</b> <br>

# %%
from scipy.spatial.distance import cdist
from sklearn import datasets
import numpy as np
import matplotlib.pyplot as plt

np.random.seed(10)

iris = datasets.load_iris()
X = iris.data[:, :2]  # we only take the first two features.
y = iris.target

print("Resposta: ",'2')

plt.scatter(X[:,0], X[:,1], c=y, cmap='viridis', s=50, alpha=0.9)
plt.title('Original Data')
plt.show(True)

#usando o método agrupamento hierárquico
k=2
clustering = cluster.AgglomerativeClustering(n_clusters=k, linkage='ward')
y_hr = clustering.fit_predict(X)

print('Mutual information score:', normalized_mutual_info_score(y_hr, y, average_method='arithmetic'))

plt.figure(figsize=(6,4))
plt.scatter(X[:,0], X[:,1], c=y_hr, cmap='viridis', s=50, alpha=0.9)
plt.xlim(4,8)
plt.ylim(1.5,4.5)
plt.title('Aglomerative clustering: Ward')
plt.show(True)

NMI_hr = []
K = range(1,10)

for i in K:    
    clustering = cluster.AgglomerativeClustering(n_clusters=i, linkage='ward')
    y_hr = clustering.fit_predict(X)
    NMI_hr.append(normalized_mutual_info_score(y_hr, y, average_method='arithmetic'))

plt.plot(K, NMI_hr, '-ro', label = 'hierarchical (Ward)')
plt.xlabel('k', fontsize = 15)
plt.ylabel('Normalized Mutual information', fontsize = 15)
plt.grid(True)
plt.legend()
plt.show()
# Out:
# Resposta:  2
# Mutual information score: 0.590757522780414
